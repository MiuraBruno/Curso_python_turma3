# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#PANDAS

# %%
import numpy as np
import pandas as pd

# %%
val 'yy-mm-dd'

# %%
dir(pd)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Panel',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseDtype',
#  'SparseSeries',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__Datetime',
#  '__DatetimeSub',
#  '__SparseArray',
#  '__SparseArraySub',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
# ...

# %%
#focaremos em Series e DataFrame

# %% [markdown]
# ## Series
# uma mistura de dicionario com array

# %%
#alguns tipos para auxilio
l1 = ['a','b','c']
l2 = [10,20,30]
arr = np.array([10,20,30])
d = {'a':10,'b':20,'c':30}

# %%
#como Criar uma Series

# %%
ser = pd.Series(l1)

# %%
ser[0]
# Out:
# 'a'

# %%
ser
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
s = pd.Series(l1)

# %%
ser2 = pd.Series(data=l1,index=l2)

# %%
ser2[30]
# Out:
# 'c'

# %%
d
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
ser3 = pd.Series(d)

# %%
ser3['c']
# Out:
# 30

# %%
pd.Series(l1,arr)
# Out:
# 10    a
# 20    b
# 30    c
# dtype: object

# %%
pd.Series(data=arr,index=l1)
# Out:
# a    10
# b    20
# c    30
# dtype: int32

# %%
ser1 = pd.Series(data=[1,2,3,4],index=['EUA','Alemanha','Russia','Japão'])

# %%
ser1['EUA']
# Out:
# 1

# %%
#Acessando o conteudo de uma Serie

# %%
ser1['Japão']
# Out:
# 4

# %%
ser1
# Out:
# EUA         1
# Alemanha    2
# Russia      3
# Japão       4
# dtype: int64

# %%
#operações com series

# %%
ser1 + 99999
# Out:
# EUA         100000
# Alemanha    100001
# Russia      100002
# Japão       100003
# dtype: int64

# %%
ser1 ** 4
# Out:
# EUA           1
# Alemanha     16
# Russia       81
# Japão       256
# dtype: int64

# %%
ser1 + [1,2,3,4]
# Out:
# EUA         2
# Alemanha    4
# Russia      6
# Japão       8
# dtype: int64

# %%
#operações entre series

# %%
ser2 = pd.Series([1,2,3,4],index=['Brasil','Alemanha','EUA','Japão'])

# %%
ser1
# Out:
# EUA         1
# Alemanha    2
# Russia      3
# Japão       4
# dtype: int64

# %%
ser2
# Out:
# Brasil      1
# Alemanha    2
# EUA         3
# Japão       4
# dtype: int64

# %%
ser1 + ser2
# Out:
# Alemanha    4.0
# Brasil      NaN
# EUA         4.0
# Japão       8.0
# Russia      NaN
# dtype: float64

# %% [markdown]
# # Nulo no Python é None

# %% [markdown]
# # Nulo no Pandas é NaN

# %% [markdown]
# # dataframe
# ### é um conjunto de series
# ### Dataframe é um tipo de dado IMUTÁVEL assim como a tupla

# %%
arr = np.arange(20).reshape(5,4)
indice = [10,20,30,40,50]
colunas = 'A B C D'.split()

# %%
# Out:
# ['A', 'B', 'C', 'D']

# %%
pd.DataFrame(data=arr,index=indice,columns=colunas)
# Out:
#      A   B   C   D
# 10   0   1   2   3
# 20   4   5   6   7
# 30   8   9  10  11
# 40  12  13  14  15
# 50  16  17  18  19

# %%
df = pd.DataFrame(data=arr,index=indice,columns=colunas)

# %% [markdown]
# ## Acessando elementos de um dataframe

# %% [markdown]
# ### Fazendo um depara de pandas com sintaxe SQL

# %% [markdown]
# ### SELECT C FROM DF

# %%
df
# Out:
#      A   B   C   D
# 10   0   1   2   3
# 20   4   5   6   7
# 30   8   9  10  11
# 40  12  13  14  15
# 50  16  17  18  19

# %%
df['C']
# Out:
# 10     2
# 20     6
# 30    10
# 40    14
# 50    18
# Name: C, dtype: int32

# %%
df.A
# Out:
# 10     0
# 20     4
# 30     8
# 40    12
# 50    16
# Name: A, dtype: int32

# %% [markdown]
# ### SELECT C, B, D, A FROM DF

# %%
df[['C','B','D','A']]
# Out:
#      C   B   D   A
# 10   2   1   3   0
# 20   6   5   7   4
# 30  10   9  11   8
# 40  14  13  15  12
# 50  18  17  19  16

# %% [markdown]
# ### operações com dataframe

# %%
df
# Out:
#      A   B   C   D
# 10   0   1   2   3
# 20   4   5   6   7
# 30   8   9  10  11
# 40  12  13  14  15
# 50  16  17  18  19

# %%
df + 1000
# Out:
#        A     B     C     D
# 10  1000  1001  1002  1003
# 20  1004  1005  1006  1007
# 30  1008  1009  1010  1011
# 40  1012  1013  1014  1015
# 50  1016  1017  1018  1019

# %%
df * 7
# Out:
#       A    B    C    D
# 10    0    7   14   21
# 20   28   35   42   49
# 30   56   63   70   77
# 40   84   91   98  105
# 50  112  119  126  133

# %%
df + [1,2,3,4]
# Out:
#      A   B   C   D
# 10   1   3   5   7
# 20   5   7   9  11
# 30   9  11  13  15
# 40  13  15  17  19
# 50  17  19  21  23

# %%
df + df
# Out:
#      A   B   C   D
# 10   0   2   4   6
# 20   8  10  12  14
# 30  16  18  20  22
# 40  24  26  28  30
# 50  32  34  36  38

# %% [markdown]
# ### soma entre colunas

# %%
df['A'] + df['B']
# Out:
# 10     1
# 20     9
# 30    17
# 40    25
# 50    33
# dtype: int32

# %%
((df['A'] + df['B']) * df['C'])/df['D']
# Out:
# 10     0.666667
# 20     7.714286
# 30    15.454545
# 40    23.333333
# 50    31.263158
# dtype: float64

# %% [markdown]
# ## criar novas colunas e aplicar algum cálculo

# %%
df['Nova_coluna'] = df['A'] * 1000

# %%
df
# Out:
#      A   B   C   D  Nova_coluna
# 10   0   1   2   3            0
# 20   4   5   6   7         4000
# 30   8   9  10  11         8000
# 40  12  13  14  15        12000
# 50  16  17  18  19        16000

# %%
df['Nova_coluna'] = 0

# %%
df['C'] = df['A'] + df['B']

# %%
df
# Out:
#      A   B   C   D  Nova_coluna
# 10   0   1   1   3            0
# 20   4   5   9   7            0
# 30   8   9  17  11            0
# 40  12  13  25  15            0
# 50  16  17  33  19            0

# %%
#deletando registro de linha baseado no indice
df.drop(10,axis=0)
# Out:
#      A   B   C   D  Nova_coluna
# 20   4   5   9   7            0
# 30   8   9  17  11            0
# 40  12  13  25  15            0
# 50  16  17  33  19            0

# %%
#deletando registro de uma colunas basedo na nome da coluna
df.drop('Nova_coluna',axis=1)
# Out:
#      A   B   C   D
# 10   0   1   1   3
# 20   4   5   9   7
# 30   8   9  17  11
# 40  12  13  25  15
# 50  16  17  33  19

# %%
df
# Out:
#      A   B   C   D  Nova_coluna
# 10   0   1   1   3            0
# 20   4   5   9   7            0
# 30   8   9  17  11            0
# 40  12  13  25  15            0
# 50  16  17  33  19            0

# %% [markdown]
# # Importancia do comando inplace=True

# %%
df.drop('Nova_coluna',axis=1,inplace=True)

# %%
df
# Out:
#      A   B   C   D
# 10   0   1   1   3
# 20   4   5   9   7
# 30   8   9  17  11
# 40  12  13  25  15
# 50  16  17  33  19

# %%
df = df.drop(10,axis=0)

# %%
df
# Out:
#      A   B   C   D
# 20   4   5   9   7
# 30   8   9  17  11
# 40  12  13  25  15
# 50  16  17  33  19

# %% [markdown]
# ### diferença dos comandos LOC e ILOC

# %%
df
# Out:
#      A   B   C   D
# 20   4   5   9   7
# 30   8   9  17  11
# 40  12  13  25  15
# 50  16  17  33  19

# %%
#loc acessa a linha de todas as  coluna atraves do indice e transforma em uma Serie
df.loc[20]
# Out:
# A    99999
# B        5
# C        9
# D        7
# Name: 20, dtype: int32

# %%
df.loc[20][0] = 9999

# %%
df
# Out:
#        A   B   C   D
# 20  9999   5   9   7
# 30     8   9  17  11
# 40    12  13  25  15
# 50    16  17  33  19

# %%
df.loc[[20,40,30,20,20,20]]
# Out:
#        A   B   C   D
# 20  9999   5   9   7
# 40    12  13  25  15
# 30     8   9  17  11
# 20  9999   5   9   7
# 20  9999   5   9   7
# 20  9999   5   9   7

# %%
df
# Out:
#        A   B   C   D
# 20  9999   5   9   7
# 30     8   9  17  11
# 40    12  13  25  15
# 50    16  17  33  19

# %%
df.loc[[50,40],['B','D','C']]
# Out:
#      B   D   C
# 50  17  19  33
# 40  13  15  25

# %%
df.loc[[20,30],['B','C']]
# Out:
#     B   C
# 20  5   9
# 30  9  17

# %%
#ILOC

# %%
df
# Out:
#        A   B   C   D
# 20  9999   5   9   7
# 30     8   9  17  11
# 40    12  13  25  15
# 50    16  17  33  19

# %%
#df.iloc[linhas][colunas]
df.iloc[2][1:3]
# Out:
# B    13
# C    25
# Name: 40, dtype: int32

# %%
df.iloc[-1][1:]
# Out:
# B    17
# C    33
# D    19
# Name: 50, dtype: int32

# %%
df
# Out:
#        A   B   C   D
# 20  9999   5   9   7
# 30     8   9  17  11
# 40    12  13  25  15
# 50    16  17  33  19

# %%
df.iloc[1:3,1:3]
# Out:
#      B   C
# 30   9  17
# 40  13  25

# %%
df.iloc[:2,:3]
# Out:
#        A  B   C
# 20  9999  5   9
# 30     8  9  17

# %% [markdown]
# ### LOC acesso por indice e nome da coluna
# ### ILOC acesso com se fosse lista (posicional)

# %% [markdown]
# # Como fazer um WHERE

# %%
df
# Out:
#        A   B   C   D
# 20  9999   5   9   7
# 30     8   9  17  11
# 40    12  13  25  15
# 50    16  17  33  19

# %%
df > 10
# Out:
#         A      B      C      D
# 20   True  False  False  False
# 30  False  False   True   True
# 40   True   True   True   True
# 50   True   True   True   True

# %%
df == 13
# Out:
#         A      B      C      D
# 20  False  False  False  False
# 30  False  False  False  False
# 40  False   True  False  False
# 50  False  False  False  False

# %%
df != 9999
# Out:
#         A     B     C     D
# 20  False  True  True  True
# 30   True  True  True  True
# 40   True  True  True  True
# 50   True  True  True  True

# %%
'''
SELECT 
    * 
FROM DF
WHERE 
    A = 8 
    OR B = 8
    OR C = 8 
    OR D = 8
'''
# Out:
# '\nSELECT \n    * \nFROM DF\nWHERE \n    A = 8 \n    OR B = 8\n    OR C = 8 \n    OR D = 8\n'

# %%
df == 8
# Out:
#         A      B      C      D
# 20  False  False  False  False
# 30   True  False  False  False
# 40  False  False  False  False
# 50  False  False  False  False

# %%
df[df >= 10]
# Out:
#          A     B     C     D
# 20  9999.0   NaN   NaN   NaN
# 30     NaN   NaN  17.0  11.0
# 40    12.0  13.0  25.0  15.0
# 50    16.0  17.0  33.0  19.0

# %%
'''
SELECT 
    B
FROM DF 
WHERE 
    A == 4
'''

# %%
df[df['A'] == 8]['B']
# Out:
# 30    9
# Name: B, dtype: int32

# %%
df[df['A'] == 4]['B']

# %%
'''
SELECT
    C 
FROM
WHERE 
    A = 
    AND B  = 
'''

# %%
df
# Out:
#        A   B   C   D
# 20  9999   5   9   7
# 30     8   9  17  11
# 40    12  13  25  15
# 50    16  17  33  19

# %%
df[(df['A'] == 8) & (df['B'] == 9)]['C']
# Out:
# 30    17
# Name: C, dtype: int32

# %%
df[(df['A'] == 8) & (df['B'] == 9)]['C']

# %%
'''
SELECT
    C 
FROM
WHERE 
    A = 
    OR B  = 
'''

# %%
df[(df['A'] == 8) | (df['B'] == 5)]['C']
# Out:
# 20     9
# 30    17
# Name: C, dtype: int32

# %%
df[(df['A'] == 8) | (df['B'] == 5)]['C']

# %%
df
# Out:
#        A   B   C   D
# 20  9999   5   9   7
# 30     8   9  17  11
# 40    12  13  25  15
# 50    16  17  33  19

# %% [markdown]
# ### df.reset_index()

# %%
df.reset_index()
# Out:
#    index     A   B   C   D
# 0     20  9999   5   9   7
# 1     30     8   9  17  11
# 2     40    12  13  25  15
# 3     50    16  17  33  19

# %% [markdown]
# ### set_index

# %%
df.set_index('A')
# Out:
#        B   C   D
# A
# 9999   5   9   7
# 8      9  17  11
# 12    13  25  15
# 16    17  33  19

# %% [markdown]
# # Tratando Nulos

# %%
v = [[0,1,2],[3,4,np.nan],[5,np.nan,np.nan]]
arr = np.array(v)

# %%
df = pd.DataFrame(data=arr)

# %%
df
# Out:
#      0    1    2
# 0  0.0  1.0  2.0
# 1  3.0  4.0  NaN
# 2  5.0  NaN  NaN

# %%
#exclui as linhas que contenho NaN
df.dropna()
# Out:
#      0    1    2
# 0  0.0  1.0  2.0

# %%
#substinui o NaN por algo conveniente
df.fillna(0)
# Out:
#      0    1    2
# 0  0.0  1.0  2.0
# 1  3.0  4.0  0.0
# 2  5.0  0.0  0.0

# %%
df.fillna('Não informado')
# Out:
#      0              1              2
# 0  0.0              1              2
# 1  3.0              4  Não informado
# 2  5.0  Não informado  Não informado

# %%
df.fillna('NULO')
# Out:
#      0     1     2
# 0  0.0     1     2
# 1  3.0     4  NULO
# 2  5.0  NULO  NULO

# %% [markdown]
# ## Cálculos prontos no pandas

# %%
#média

# %%
arr = np.arange(20).reshape(5,4)
indice = [10,20,30,40,50]
colunas = 'A B C D'.split()
df = pd.DataFrame(data=arr,index=indice,columns=colunas)[['A','B']].iloc[:3]

# %%
df
# Out:
#     A  B
# 10  0  1
# 20  4  5
# 30  8  9

# %%
df.sum()
# Out:
# A    12
# B    15
# dtype: int64

# %%
df.sum(axis=1)
# Out:
# 10     1
# 20     9
# 30    17
# dtype: int64

# %%
#a média desconsidera os nulos
df.sum(axis=0)
# Out:
# A    12
# B    15
# dtype: int64

# %%
df.mean(axis=0)
# Out:
# A    4.0
# B    5.0
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 10    0.5
# 20    4.5
# 30    8.5
# dtype: float64

# %% [markdown]
# # GROUP BY

# %%
valores = {
    'especies' : ['versicolor','setosa','virginica','versicolor','setosa','virginica','versicolor','setosa','virginica']
    ,'petala' : [1,2,3,2,3,1,2,3,4]
    ,'sepala' : [4,5,6,5,7,5,3,4,5]
}

# %%
df = pd.DataFrame(valores)

# %%
df
# Out:
#      especies  petala  sepala
# 0  versicolor       1       4
# 1      setosa       2       5
# 2   virginica       3       6
# 3  versicolor       2       5
# 4      setosa       3       7
# 5   virginica       1       5
# 6  versicolor       2       3
# 7      setosa       3       4
# 8   virginica       4       5

# %%
'''
SELECT 
    ESPECIES
    ,SUM(VALORES)
FROM DF 
GROUP BY ESPECIES

SELECT 
    ESPECIES
    ,MEAN(VALORES)
FROM DF 
GROUP BY ESPECIES

'''

# %%
df.groupby('especies').sum()
# Out:
#             petala  sepala
# especies
# setosa           8      16
# versicolor       5      12
# virginica        8      16

# %%
df.groupby('especies').mean()
# Out:
#               petala    sepala
# especies
# setosa      2.666667  5.333333
# versicolor  1.666667  4.000000
# virginica   2.666667  5.333333

# %% [markdown]
# # IRIS.CSV em Pandas

# %%
df = pd.read_csv('iris.csv',sep=';',encoding='UTF-8')

# %%
v = dir(df)
for i in v:
    if 'sql' in i:
        print(i)
# Out:
# to_sql

# %%
dir(pd)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Panel',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseDtype',
#  'SparseSeries',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__Datetime',
#  '__DatetimeSub',
#  '__SparseArray',
#  '__SparseArraySub',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
# ...

# %%
df.head()
# Out:
#    Id  Comprimento_Sepala  Largura_Sepala  Comprimento_Petala  Largura_Petala  \
# 0   1                 5.1             3.5                 1.4             0.2
# 1   2                 4.9             3.0                 1.4             0.2
# 2   3                 4.7             3.2                 1.3             0.2
# 3   4                 4.6             3.1                 1.5             0.2
# 4   5                 5.0             3.6                 1.4             0.2
#
#   Especie
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
df.groupby('Especie').mean()
# Out:
#                Id  Comprimento_Sepala  Largura_Sepala  Comprimento_Petala  \
# Especie
# setosa       25.5               5.006           3.418               1.464
# versicolor   75.5               5.936           2.770               4.260
# virginica   125.5               6.588           2.974               5.552
#
#             Largura_Petala
# Especie
# setosa               0.244
# versicolor           1.326
# virginica            2.026

# %%
df.groupby('Especie').mean().to_csv('resposta.csv',sep='|')

# %%
dir(df)
# Out:
# ['Comprimento_Petala',
#  'Comprimento_Sepala',
#  'Especie',
#  'Id',
#  'Largura_Petala',
#  'Largura_Sepala',
#  'T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
# ...

# %%
df.groupby('Especie').describe().to_csv('exemplo_describe.csv',sep=';')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  150 non-null    int64
#  1   Comprimento_Sepala  150 non-null    float64
#  2   Largura_Sepala      150 non-null    float64
#  3   Comprimento_Petala  150 non-null    float64
#  4   Largura_Petala      150 non-null    float64
#  5   Especie             150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# # Union all

# %%
dados1 =  np.array(list(map(lambda x: 'A' + str(x), range(16)))).reshape(4,4)
dados2 =  np.array(list(map(lambda x: 'B' + str(x), range(16)))).reshape(4,4)
dados3 =  np.array(list(map(lambda x: 'C' + str(x), range(16)))).reshape(4,4)
dados4 =  np.array(list(map(lambda x: 'D' + str(x), range(16)))).reshape(4,4)
dados5 =  np.array(list(map(lambda x: 'E' + str(x), range(16)))).reshape(4,4)

colunas = ['col1','col2','col3','col4']

df1 = pd.DataFrame(dados1,columns=colunas)
df2 = pd.DataFrame(dados2,columns=colunas)
df3 = pd.DataFrame(dados3,columns=colunas)
df4 = pd.DataFrame(dados4,columns=colunas,index=[1,2,3,4])
df5 = pd.DataFrame(dados5,columns=colunas,index=[5,6,7,8])

# %%
'''
SELECT 
    * 
FROM DF1

UNION ALL 

SELECT 
    *
FROM DF2

'''

# %%
pd.concat([df1,df2])
# Out:
#   col1 col2 col3 col4
# 0   A0   A1   A2   A3
# 1   A4   A5   A6   A7
# 2   A8   A9  A10  A11
# 3  A12  A13  A14  A15
# 0   B0   B1   B2   B3
# 1   B4   B5   B6   B7
# 2   B8   B9  B10  B11
# 3  B12  B13  B14  B15

# %%
pd.concat([df4,df5])
# Out:
#   col1 col2 col3 col4
# 1   D0   D1   D2   D3
# 2   D4   D5   D6   D7
# 3   D8   D9  D10  D11
# 4  D12  D13  D14  D15
# 5   E0   E1   E2   E3
# 6   E4   E5   E6   E7
# 7   E8   E9  E10  E11
# 8  E12  E13  E14  E15

# %%
pd.concat([df1,df2,df3,df4,df5])
# Out:
#   col1 col2 col3 col4
# 0   A0   A1   A2   A3
# 1   A4   A5   A6   A7
# 2   A8   A9  A10  A11
# 3  A12  A13  A14  A15
# 0   B0   B1   B2   B3
# 1   B4   B5   B6   B7
# 2   B8   B9  B10  B11
# 3  B12  B13  B14  B15
# 0   C0   C1   C2   C3
# 1   C4   C5   C6   C7
# 2   C8   C9  C10  C11
# 3  C12  C13  C14  C15
# 1   D0   D1   D2   D3
# 2   D4   D5   D6   D7
# 3   D8   D9  D10  D11
# 4  D12  D13  D14  D15
# 5   E0   E1   E2   E3
# 6   E4   E5   E6   E7
# 7   E8   E9  E10  E11
# 8  E12  E13  E14  E15

# %% [markdown]
# # JOIN

# %%
pd.concat([df1,df2],axis=1)
# Out:
#   col1 col2 col3 col4 col1 col2 col3 col4
# 0   A0   A1   A2   A3   B0   B1   B2   B3
# 1   A4   A5   A6   A7   B4   B5   B6   B7
# 2   A8   A9  A10  A11   B8   B9  B10  B11
# 3  A12  A13  A14  A15  B12  B13  B14  B15

# %%
df4
# Out:
#   col1 col2 col3 col4
# 1   D0   D1   D2   D3
# 2   D4   D5   D6   D7
# 3   D8   D9  D10  D11
# 4  D12  D13  D14  D15

# %%
df5
# Out:
#   col1 col2 col3 col4
# 5   E0   E1   E2   E3
# 6   E4   E5   E6   E7
# 7   E8   E9  E10  E11
# 8  E12  E13  E14  E15

# %%
pd.concat([df4,df5],axis=1)
# Out:
#   col1 col2 col3 col4 col1 col2 col3 col4
# 1   D0   D1   D2   D3  NaN  NaN  NaN  NaN
# 2   D4   D5   D6   D7  NaN  NaN  NaN  NaN
# 3   D8   D9  D10  D11  NaN  NaN  NaN  NaN
# 4  D12  D13  D14  D15  NaN  NaN  NaN  NaN
# 5  NaN  NaN  NaN  NaN   E0   E1   E2   E3
# 6  NaN  NaN  NaN  NaN   E4   E5   E6   E7
# 7  NaN  NaN  NaN  NaN   E8   E9  E10  E11
# 8  NaN  NaN  NaN  NaN  E12  E13  E14  E15

# %%
pd.concat([df4,df5],axis=1).fillna(0)
# Out:
#   col1 col2 col3 col4 col1 col2 col3 col4
# 1   D0   D1   D2   D3    0    0    0    0
# 2   D4   D5   D6   D7    0    0    0    0
# 3   D8   D9  D10  D11    0    0    0    0
# 4  D12  D13  D14  D15    0    0    0    0
# 5    0    0    0    0   E0   E1   E2   E3
# 6    0    0    0    0   E4   E5   E6   E7
# 7    0    0    0    0   E8   E9  E10  E11
# 8    0    0    0    0  E12  E13  E14  E15

# %%
colunas = ['id','nome','numero']
dados1 = [[0,'a',55.0,],[1,'b',12.0],[2,'c',98.5]]
dados2 = [[0,'a',32.8],[2,'d',871.9],[4,'e',812.123]]
t1 = pd.DataFrame(dados1,columns=colunas)
t2 = pd.DataFrame(dados2,columns=colunas)

# %%
t1
# Out:
#    id nome  numero
# 0   0    a    55.0
# 1   1    b    12.0
# 2   2    c    98.5

# %%
t2
# Out:
#    id nome   numero
# 0   0    a   32.800
# 1   2    d  871.900
# 2   4    e  812.123

# %%
pd.merge(t1,t2,how='inner',on='id')
# Out:
#    id nome_x  numero_x nome_y  numero_y
# 0   0      a      55.0      a      32.8
# 1   2      c      98.5      d     871.9

# %%
pd.merge(t1,t2,how='inner',on='id')
# Out:
#    id nome_x  numero_x nome_y  numero_y
# 0   0      a      55.0      a      32.8
# 1   2      c      98.5      d     871.9

# %%
pd.merge(t1,t2,how='left',left_on='id',right_on = 'id').fillna('null')
# Out:
#    id nome_x  numero_x nome_y numero_y
# 0   0      a      55.0      a     32.8
# 1   1      b      12.0   null     null
# 2   2      c      98.5      d    871.9

# %%
pd.merge(t1,t2,how='right',left_on='id',right_on = 'id').fillna('null')
# Out:
#    id nome_x numero_x nome_y  numero_y
# 0   0      a       55      a    32.800
# 1   2      c     98.5      d   871.900
# 2   4   null     null      e   812.123

# %%
df_x = pd.merge(t1,t2,how='inner',on='id')
df_x['somatorio'] = df_x['numero_x'] + df_x['numero_y']
df_x
# Out:
#    id nome_x  numero_x nome_y  numero_y  somatorio
# 0   0      a      55.0      a      32.8       87.8
# 1   2      c      98.5      d     871.9      970.4

# %% [markdown]
# # distinct

# %%
dados = {'id':[111111,111111,2222222,2222222],'nomes':['aaaa','bbb','cccc','dddd'],'valores':[1231,545,4637,675]}
df = pd.DataFrame(dados)

# %%
df
# Out:
#         id nomes  valores
# 0   111111  aaaa     1231
# 1   111111   bbb      545
# 2  2222222  cccc     4637
# 3  2222222  dddd      675

# %%
df['id'].unique()
# Out:
# array([ 111111, 2222222], dtype=int64)

# %%
df['id'].value_counts()
# Out:
# 111111     2
# 2222222    2
# Name: id, dtype: int64

# %%
df['nomes'].value_counts() > 1
# Out:
# bbb     False
# aaaa    False
# cccc    False
# dddd    False
# Name: nomes, dtype: bool

# %% [markdown]
# # order by

# %%
df.sort_values('id',ascending=False)
# Out:
#         id nomes  valores
# 2  2222222  cccc     4637
# 3  2222222  dddd      675
# 0   111111  aaaa     1231
# 1   111111   bbb      545

# %% [markdown]
# # apply

# %%
df['nomes'].apply(len)
# Out:
# 0    4
# 1    3
# 2    4
# 3    4
# Name: nomes, dtype: int64

# %%
def test(x):
    return x * 1000/3

# %%
df['valores'].apply(test)
# Out:
# 0    4.103333e+05
# 1    1.816667e+05
# 2    1.545667e+06
# 3    2.250000e+05
# Name: valores, dtype: float64

# %%
df['nomes'].apply(lambda x: x.upper())
# Out:
# 0    AAAA
# 1     BBB
# 2    CCCC
# 3    DDDD
# Name: nomes, dtype: object
