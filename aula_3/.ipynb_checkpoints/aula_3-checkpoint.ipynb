# %%
#dicionários

# %% [markdown]
# ![Captura%20de%20Tela%20%28187%29.png](attachment:Captura%20de%20Tela%20%28187%29.png)

# %%
l = []

# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
d = {
    'Nome':'Miura'
    ,'Idade':24
    ,'número':3.141592
    ,1234:['a','v']
}

# %%
print(d)
# Out:
# {'Nome': 'Miura', 'Idade': 24, 'número': 3.141592, 1234: ['a', 'v']}

# %%
d[1234]
# Out:
# ['a', 'v']

# %%
d['Nome']
# Out:
# 'Miura'

# %%
d['Idade']
# Out:
# 24

# %%
d.keys()
# Out:
# dict_keys(['Nome', 'Idade', 'número', 1234])

# %%
d.values()
# Out:
# dict_values(['Miura', 24, 3.141592, ['a', 'v']])

# %%
d.items()
# Out:
# dict_items([('Nome', 'Miura'), ('Idade', 24), ('número', 3.141592), (1234, ['a', 'v'])])

# %%
for i in d:
    print(i)
    print(d[i])
    print('*'*10)
# Out:
# Nome
# Miura
# **********
# Idade
# 24
# **********
# número
# 3.141592
# **********
# 1234
# ['a', 'v']
# **********

# %%
for i,j in enumerate(d):
    print(i)
    print(j)
    print('*'*30)
# Out:
# 0
# Nome
# ******************************
# 1
# Idade
# ******************************
# 2
# número
# ******************************
# 3
# 1234
# ******************************

# %%
d
# Out:
# {'Nome': 'Miura', 'Idade': 24, 'número': 3.141592, 1234: ['a', 'v']}

# %%
d['CEP'] = '07073-150'

# %%
print(d)
# Out:
# {'Nome': 'Miura', 'Idade': 24, 'número': 3.141592, 1234: ['a', 'v'], 'CEP': '07073-150'}

# %%
d['Nome'] = 'Miura-San'

# %%
print(d)
# Out:
# {'Nome': 'Miura-San', 'Idade': 24, 'número': 3.141592, 1234: ['a', 'v'], 'CEP': '07073-150'}

# %%
help(d.clear)
# Out:
# Help on built-in function clear:
#
# clear(...) method of builtins.dict instance
#     D.clear() -> None.  Remove all items from D.

# %%
d.clear()

# %%
print(d)
# Out:
# {}

# %%
dir(d)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
d.pop('Nome')
# Out:
# 'Miura-San'

# %%
d
# Out:
# {}

# %% [markdown]
# # parece um bug

# %%
a = [1,2,3,4]

# %%
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
b = a

# %%
print(b)
# Out:
# [1, 2, 3, 4, 5]

# %%
b.append(5)

# %% [markdown]
# # como resolver

# %%
a
# Out:
# [1, 2, 3, 4, 5]

# %%
b = a.copy()

# %%
b
# Out:
# [1, 2, 3, 4, 5]

# %%
b.append(6)

# %%
print(b)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
a[1000]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-49-ccba6d6a7638> in <module>
# ----> 1 a[1000]
#
# IndexError: list index out of range

# %% [markdown]
# **como rodar um programa python na linha de comando**
