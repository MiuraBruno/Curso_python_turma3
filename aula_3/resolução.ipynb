# %% [markdown]
# # Resolvendo o exercício do LEDs

# %% [markdown]
# https://www.urionlinejudge.com.br/judge/pt/problems/view/1168

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
leds = {'1':2
        ,'2':5
        ,'3':5
        ,'4':4
        ,'5':5
        ,'6':6
        ,'7':3
        ,'8':7
        ,'9':6
        ,'0':6
       }

# %%
qtd = int(input())
# Out:
# 3

# %%
for i in range(qtd):
    numero = input()
    total = 0
    for j in numero:
        total = total + leds[j]
    print('%d leds' %(total))
# Out:
# 123
# 12 leds
# 3
# 5 leds
# 2
# 5 leds
