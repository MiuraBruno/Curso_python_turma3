# %%
#criar uma função para calular a área do triângulo

# %% [markdown]
# ![area-do-triangulo-2.png](attachment:area-do-triangulo-2.png)

# %%
#criar uma função para calular a área do trapézio

# %% [markdown]
# ![area-trapezio-1200x675.jpg](attachment:area-trapezio-1200x675.jpg)

# %%
#criar uma função para calular a área do círculo, adote PI como 3.14159

# %% [markdown]
# ![download.png](attachment:download.png)
